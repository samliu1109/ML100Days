# %% [markdown]
# # [作業目標]
# - 利用範例的創建方式, 創建一組資料, 並練習如何取出最大值

# %% [markdown]
# # [作業重點]
# - 練習創立 DataFrame (In[2])
# - 如何取出口數最多的國家 (In[3], Out[3])

# %% [markdown]
# ## 練習時間
# 在小量的資料上，我們用眼睛就可以看得出來程式碼是否有跑出我們理想中的結果
#
# 請嘗試想像一個你需要的資料結構 (裡面的值可以是隨機的)，然後用上述的方法把它變成 pandas DataFrame
#
# #### Ex: 想像一個 dataframe 有兩個欄位，一個是國家，一個是人口，求人口數最多的國家
#
# ### Hints: [隨機產生數值](https://blog.csdn.net/christianashannon/article/details/78867204)

# %%
import pandas as pd
import numpy as np

# %%
record1 = pd.Series({'Name': 'Westbrook','Team': 'Wizards','Score': 99})
record2 = pd.Series({'Name': 'James','Team': 'Lakers','Score': 90})
record3 = pd.Series({'Name': 'Curry','Team': 'Warriors','Score': 60})
df = pd.DataFrame([record1, record2, record3],index=['1', '2', '3'])
df.head()
# Out:
#         Name      Team  Score
# 1  Westbrook   Wizards     99
# 2      James    Lakers     90
# 3      Curry  Warriors     60

# %%
df.max()
# Out:
# Name     Westbrook
# Team       Wizards
# Score           99
# dtype: object
